# %%
# %load_ext autoreload
# %autoreload 2

# %%
#import dask.dataframe as dd
import pandas as pd
import seaborn as sns

# %%
pd.set_option("max_rows", 100)
pd.set_option("max_colwidth", 2000)

# %%
df = pd.read_csv("./data/Corona_NLP_train.csv")
df_test = pd.read_csv("./data/Corona_NLP_test.csv")
#df = dd.from_pandas(df, npartitions=1)
#df = df.persist()

# %% [markdown]
# # Data Exploration
# Let's begin with examining a few datapoints and attributes.

# %%
df.head(5)
# Out:
#    UserName  ScreenName   Location     TweetAt  \
# 0      3799       48751     London  16-03-2020
# 1      3800       48752         UK  16-03-2020
# 2      3801       48753  Vagabonds  16-03-2020
# 3      3802       48754        NaN  16-03-2020
# 4      3803       48755        NaN  16-03-2020
#
#                                                                                                                                                                                                                                                                                                                         OriginalTweet  \
# 0                                                                                                                                                                                                                     @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/iFz9FAn2Pa and https://t.co/xX6ghGFzCC and https://t.co/I2NlzdxNo8
# 1                                                                                       advice Talk to your neighbours family to exchange phone numbers create contact list with phone numbers of neighbours schools employer chemist GP set up online shopping accounts if poss adequate supplies of regular meds but not over order
# 2                                                                                                                                                                                                 Coronavirus Australia: Woolworths to give elderly, disabled dedicated shopping hours amid COVID-19 outbreak https://t.co/bInCA9Vp8P
# 3   My food stock is not the only one which is empty...\r\r\n\r\r\nPLEASE, don't panic, THERE WILL BE ENOUGH FOOD FOR EVERYONE if you do not take more than you need. \r\r\nStay calm, stay safe.\r\r\n\r\r\n#COVID19france #COVID_19 #COVID19 #coronavirus #confinement #Confinementotal #ConfinementGeneral https://t.co/zrlG0Z520j
# 4  Me, ready to go at supermarket during the #COVID19 outbreak.\r\r\n\r\r\nNot because I'm paranoid, but because my food stock is litteraly empty. The #coronavirus is a serious thing, but please, don't panic. It causes shortage...\r\r\n\r\r\n#CoronavirusFrance #restezchezvous #StayAtHome #confinement https://t.co/usmuaLq72n
#
#             Sentiment
# 0             Neutral
# 1            Positive
# 2            Positive
# 3            Positive
# 4  Extremely Negative

# %%
set(df.Sentiment)
# Out:
# {'Extremely Negative', 'Extremely Positive', 'Negative', 'Neutral', 'Positive'}

# %% [markdown]
# There are some immediate observations about the tweets:
#
# Obviously there are hashstags, which are concatenations of words, which might not be able to be tokenized easily. Hashtags could, however be extracted as a separate feature.
#
# Some tweets contain URL, which might not be easily processed within standard NLP pipelines.
#
# Some tweets contain tab and newline characters ('\n' or '\r').
#
# The location attributes seems not to correspond to physical information in a lot of cases. If this attribute was to be used, there would be a need for complex data cleaning.

# %%
set(df.Location)
# Out:
# {nan,
#  'Coimbatore',
#  'https://www.academia.edu/',
#  'Heathrow, FL',
#  'instagram: @CollegeStudent',
#  'E?ITE E??I?E ??E?TI?E ?T??IO',
#  'Bracknell',
#  'TN',
#  'Anne Arundel County, MD',
#  'San Diego County',
#  'Worldwide  ',
#  'Portugal',
#  'cape cod',
#  'Indiana',
#  'OPEN TO THE PUBLIC ',
#  'Canada , NS ',
#  'El Segundo, CA',
#  'Brockworth, England',
#  'Lingen, Biene',
#  'AZ, UT, MT, AK, WY',
#  'Joburg and wherever life takes',
#  'Durban ',
#  'A Hesse in MUC and CGN & DUS',
#  'Kanpur/Mumbai',
#  'Springfield, IL',
#  'Des Moines, IA',
#  'KC-LIMA',
#  'North Haven, CT',
#  '680581',
#  'Winnipeg, MB Canada',
#  'Jordan College',
#  'in Wonderland..',
#  'Green Bay, WI, United States',
#  'Lund, BC - Klah ah men',
#  'Milton, Canada',
#  'DC/VA USA',
#  'Wallasey, England',
#  'BACK TO THE WOODS Phila, PA',
#  'Sydney Australia',
#  'Grästorp, V. Götaland, Sweden',
#  'sydney ',
#  'Manchester, England ',
#  'The Garden State',
#  'Llanrwst',
#  'Jeddah',
#  'Brookhaven, NY, USA',
#  'Nigeria ',
#  'a pod in the universe',
#  'Bergen County, NJ',
#  'St. Louis Missouri',
#  'FL, U.S.A.',
#  'Limerick/London',
#  'Ho-Chi-Minh, Vietnam',
#  'Norwich, UK',
#  'Outside the M25',
#  'CT/ On A ??',
#  '800-342-9647',
#  'Lexington, NC',
#  'Australia,somewhere.',
#  '.',
#  'Cape Cod, MA',
#  'Catalunya,España,UE?ViaLáctea!',
#  'Los Angeles ',
#  'London (from Cetraro)',
#  'Cochrane, AB',
#  'Denver, Colo.',
#  'ovaltine - ropipa',
#  'NW10',
#  'Simco mountain : RANGE ',
#  'Tynemouth',
#  'Sydney,Australia',
#  'Dynamic Life Chiropractic',
#  'Boston/Hartford ',
#  'Sebastopol, CA',
#  'Lincoln, United Kingdom',
#  'L.A. and D.C.',
#  'United States Russia Earth ?',
#  'Hercules, CA',
#  'Lilburn, Georgia',
#  'SuruLere » Lagos « WorldWide',
#  'Burr Ridge, IL',
#  'Uniklinik RWTH Aachen',
#  'Rhode Island, USA',
#  'Newark, New Jersey',
#  'St. Petersburg, Florida',
#  ' india',
#  'New Mexico USA',
#  'Jammu &Kashmir UnionTerritory',
#  'New Castle, DE',
#  'Mexico City',
#  'Catshill, Bromsgrove',
#  'Hanford, CA',
#  'Romford, London',
#  'Ajmer, Rajasthan, India',
#  'Alameda, CA',
#  'minnesota?',
#  'Little Dunham',
#  'London, Sevenoaks',
#  'location not found.',
#  'Cincinnati, OH USA',
#  'Northern California USA',
#  'Bahawalpur,Pakistan',
#  'ÜT: 40.763238,-73.978066',
#  'United States Minor Outlying I',
#  'Minneapolis Minnesota',
#  'Chicago, NYC, Orlando, LATAM',
#  'Clearwater, Florida',
#  'Tinley Park, IL',
#  'Pittsburgh, Glasgow, Lima',
#  'Witney United Kingdom',
#  'Switzerland, Earth',
#  'Across Oregon',
#  'Central London UK',
#  'Chatham-Kent, Ontario',
#  'Somewhere out there.....',
#  'Uptown, Chicago',
#  'Undisclosed Location ',
#  'Watersmeet, Michigan',
#  'NYC ? / NJ ?',
#  'Marshfield, Ma',
#  'Wichita Falls,Texas',
#  'Huntingdon',
#  'London, UK/Alexandria, VA',
#  'windsor ',
#  'London,United Kingdom',
#  'Jaipur ',
#  'Not in a secret meeting',
#  'Litchfield, New Hampshire',
#  'End Citizens United ',
#  'Texas Hill Country',
#  'NYC,Fl,The Moon?',
#  'Spokane WA',
#  'C.Patla-Kmm/Wgl/Hyd, TS-India.',
#  'I ?? Manchester',
#  'Kettering, UK',
#  'Tacoma, Wa',
#  'Gig Harbor, WA',
#  'Swaziland ',
#  'University of Melbourne',
#  'Neustadt an der Weinstraße',
#  'Mumbai,MH,India',
#  'south east london',
#  'los angeles, california',
#  'Lancaster District',
#  'Flyovercountry ',
#  'Mumbai , Delhi India',
#  'Tours, France',
#  'Ruther Glen Virginia',
#  '#maga & read:',
#  'Madison/Dane County, WI',
#  'On Cammeraygal land',
#  'Wilayah Persekutuan Kuala Lump',
#  'Arizona City, AZ',
#  'Spectrum 995 & 363',
#  'Folkestone, Kent',
#  'Hicksville, NY',
#  'Gauteng Province',
#  'Samangan',
#  'No one cares ',
#  'Bristol/Barbès/Beyond',
#  'Assam, India, The Milky Way',
#  'My 2nd account: Ask me ',
#  'Haliburton, Ontario',
#  'Blackpool, England',
#  'Nirvana',
#  'maesteg south wales',
#  'Wherever I happen to be...',
#  'Ames, Iowa',
#  'ÜT: 59.19408,17.620422',
#  'Torrance, CA',
#  'Rainhill, England',
#  'Santa Cruz, CA',
#  'Earth ?',
#  'texas',
#  'Cambridge, Cambridgeshire',
#  'Westchester County, NY',
#  'www.facebook.com/ApplebyTIC',
#  'East Midlands, England',
#  'Kuala Lumpur Malaysia ',
#  'Seattle \x95 New York \x95 Boise',
#  'BRADFORD UK',
#  'Delft',
#  'Chikmagalur, India',
#  'Bath',
#  'Vineland, Ontatio',
#  'Elgin, IL',
#  'Bournemouth,Christchurch&Poole',
#  'Tampa, FL',
#  'Hamilton, New Zealand',
#  'PUNE',
#  'JDSupra.com',
#  'Alwar,Rajasthan,India',
#  'Hamstreet',
#  'Musing in the hexagon',
#  'La Grange, KY',
#  'Amsterdam, Berlin, Brussels, London, Oxford, Paris, Rome',
#  'Citizen of the world',
#  'Nairobi and Montreal',
#  'Marble Falls, Texas',
#  'UK, Wales, Ceredigion',
#  'Dublin City, Ireland',
#  'Probably in a toy shop!',
#  'Smithfield, NC',
#  'Miami, FL ????',
#  'Sebright, Ontario, Canada',
#  'Yogyakarta, Indonesia',
#  'Philadelphia PA, USA',
#  'Fendalton, Christchurch City',
#  'in your mind',
#  'Lancashire, Warwickshire, M6',
#  'El Dorado Hills, CA',
#  'Jax Beach and Cape Cod',
#  'Eastern WA',
#  'Notre Dame, IN',
#  'Bedford, Bedfordshire, Uk,',
#  'Battersby, England',
#  'ÜT: 42.085603,-76.828764',
#  'UK, Europe, France, BDX, Aube',
#  'Reading',
#  'an airport',
#  'Hackney,London',
#  'Mars',
#  'East Africa & SF Bay Area',
#  'Saline, Michigan',
#  'Skies',
#  'Lost in Space',
#  'brisbane Qld and Udon Thani',
#  'Hampton',
#  'London, Europe ',
#  'Dundee, Scotland',
#  'ÜT: 50.415269,-105.601237',
#  'DC  / London / Brighton',
#  'Chennai, Tamil Nadu',
#  'San Antonio, TX',
#  'Everywhere',
#  'Negara Brunei Darussalam',
#  '#worldwide ',
#  'Mokopane, South Africa',
#  'London/Yorkshire',
#  'Potatoville, ID',
#  'united stated, nation wide',
#  'Eden',
#  ' United Kingdom',
#  'Northwest Arkansas',
#  'near the rainbow',
#  'San Luis Obispo, CA',
#  'Reading, Europe',
#  'Rio de Janeiro',
#  'Windsor Ontario Canada',
#  'Somalidiid rehab in Garowe',
#  'Akron, OH, USA',
#  'Oakland, Ca',
#  'Los Angeles, CA USA',
#  'Madison, VA',
#  'West Chester, PA',
#  'Outskirts, Northern Powerhouse',
#  'NSW',
#  'Tuscaloosa, AL',
#  'West Lafayette, IN',
#  'Reading, PA',
#  'Mapleton Depot, PA',
#  'Medford, Oregon, USA',
#  'I stay at home! ',
#  'Everywhere & u are Never There',
#  'England,Wales,Endor,Somerset.',
#  'Newmarket, ON',
#  'Quetta',
#  'Milton Keynes, UK.',
#  'Limerick & Dublin',
#  'Tyuretye - Alice Springs. ',
#  'Nairobi Kenya',
#  'San Antonio',
#  'England UK ',
#  'Islamabad, Houston ',
#  '221B Baker St',
#  'Paris, TX, Fayetteville, NC',
#  'NY NY',
#  'Manila, Philippines',
#  'Reading, UK',
#  'Nigeria??',
#  'Timmins, Ontario',
#  'Wabasso, Florida',
#  'Montgomery Alabama',
#  'Australia, NZ, US, Canada, UK',
#  'CFL',
#  'Chester',
#  '51 North St/Bedminster/Bristol',
#  'Weaver Vale',
#  'Atlanta, GA, Orlando, FL',
#  'Brugge, België',
#  'Mercer County, NJ',
#  'Ambridge',
#  'Rabokala.South africa',
#  "St. John's, N.L.",
#  'Edgewater, Chicago',
#  'Los Angeles / Ventura County',
#  'British Columbia',
#  'Orlando, Florida USA',
#  'Kraków',
#  '8 offices and counting!',
#  'wonderland',
#  'Dublin, Ireland.',
#  'Hamilton, ON',
#  'Taured ',
#  'Rio de Janeiro- Brasil',
#  'Lincolnshire, England',
#  'Upper East, Ghana',
#  'Point Pleasant, NJ',
#  'Riyadh-Dubai',
#  'Los Angeles                   ',
#  'Montreal',
#  'Mid Florida, USA',
#  'Central New York',
#  'Hilversum, The Netherlands.',
#  'tennessee',
#  'Makati',
#  'World without borders',
#  'NY, Washington DC, London',
#  'St. Paul, Minnesota',
#  '1 AU',
#  'iPhone: 28.171532,-82.356063',
#  'LA, CA',
#  'Bakersfield, CA, USA',
#  'Front Range, CO',
#  'Kidderminster',
#  'Londonderry, United Kingdom',
#  'Maidstone, Kent',
#  'Ciudadana del Mundo',
#  '425, WA',
#  'CA|CT|FL|GA|KY|MA|NJ|NY|PA|RI',
#  'Pietermaritzburg & Newcastle ',
#  'Well........here, obviously.',
#  'Lake Station, IN',
#  'UKRAINE??',
#  'Town Called Malice',
#  'DMV',
#  'Forbidden 3rd floor corridor',
#  'leicester ',
#  'Lewiston, ID',
#  'Portsmouth',
#  'India, unplugged',
#  'Durham, England',
#  'Tehachapi, CA',
#  'Bristol, England',
#  'Regina, Saskatchewan Canada ',
#  'Jupiter',
#  'Hyrules',
#  'Málaga, España',
#  'southeast Michigan',
#  'Jaipur, Rajasthan, India',
#  'youtube.com/user/dude12nothin',
#  'Düsseldorf, Deutschland',
#  'Irelande du Nord',
#  'New-Delhi',
#  'Here, There, Everywhere',
#  'Not of this world ',
#  'Pangaea',
#  'Sydney, Australia',
#  'Sout,Arewa,West,Gabas, NG.',
#  'San Dimas, CA',
#  'Montgomery, AL',
#  'Madhya Pradesh, India',
#  'dj.zaleel@gmail.com',
#  'Limassol, Cyprus.',
#  'Morris County, New Jersey',
#  'Kekyslavia ',
#  'Sydney - Australia',
#  'TheSKYeveryWHERE',
#  'Auckland',
#  'Little Tangleling',
#  'Milan, Lombardy',
#  'Barking, London',
#  '127.0.0.1',
#  'Dinar World',
#  'Reigate, Surrey',
#  'Uttar Pradesh, India',
#  'Quezon City, Philippines',
#  'Albany NY 12204',
#  'SE North Dakota',
#  'Pozna?, Polska',
#  'Undisclosed location',
#  'Kenya??',
#  'Salisbury, England',
#  'oxford, ohio',
#  'North Charleston, SC',
#  'Vienna, Venice, Milan, London',
#  'Basildon, Essex',
#  '??/ Red Ocean / Middle Earth',
#  'Reality',
#  'Texoma, USA',
#  'Brescia, Lombardy??',
#  'Brooklands Motor Circuit',
#  'On Earth - no no over here',
#  'Nanaimo, British Columbia',
#  'Scottsdale, AZ',
#  'Lebanon, NH',
#  'Delaware ',
#  'Bay Area, California, USA',
#  'Seattle Area, WA',
#  'Baltimore, Md.',
#  'Bush House West Wing, 57 Aldwych, WC2B 4PJ',
#  'Brighton Lass ??',
#  'Allouez, WI',
#  'London, Kent & Göteborg',
#  'Lahore, Pakistan',
#  'Walking down the warwick road',
#  'In the forest looking 4 trees',
#  '#LLTBB #LLKC #LLBIGGLO',
#  'Emerald Group Publishing',
#  'Iacon.',
#  'Malvar, Calabarzon',
#  ' North West and Weardale',
#  'Muffin Monsters Are Everywhere',
#  'Vancouver | Toronto',
#  'Joplin MO',
#  'Boston & New Orleans',
#  'Long Ditton, Surrey',
#  'Kuching, Sarawak',
#  'Medway, MA',
#  'India',
#  'Regiolandia',
#  'Jacksonville FL',
#  'Manchester/ Leicester',
#  'Las Vegas,Clark County, Nevada',
#  'ÜT: 41.230596,-76.976382',
#  'Ballarat, Victoria',
#  'Lost in a song Old Trafford',
#  'Around',
#  "St. John's",
#  'Wenatchee, WA',
#  'Revelation ',
#  'Durban \x95 South Africa',
#  'Your moms place',
#  'Southern California',
#  'Niles, CA',
#  'Bang Rak, Thailand',
#  'Phoenix Arizona',
#  'Romford',
#  'USA and NZ',
#  'Ireland and the World Wide Web',
#  'Shitty Birmingham ',
#  'The World',
#  'Palm Beach, FL',
#  'somewhere in space',
#  'Pocatello, ID',
#  'New England ',
#  'Attleboro, MA',
#  'Dronfield, England',
#  'Edinburgh ',
#  'Longueuil, Québec, Canada',
#  'Deutschland',
#  'Frankenmuth, Michigan',
#  'Brussels & Lausanne',
#  'Barasat',
#  'Radnor, PA',
#  'Williston, ND; Bakken Oilfield',
#  'Ayrshire, Scotland',
#  'Between Breakfast And Bedtime',
#  'Vienna, VA, USA',
#  'West London, England',
#  'Harare,  Zimbabwe',
#  'Atlanta,Georgia',
#  'Ruby Red ??Land, USA',
#  "#Trump's head, rent-free!",
#  'L.A. CA',
#  '234',
#  'Texas Conservativ CyberCowboy',
#  'Coimbatore, India',
#  'Nevaland',
#  'Portland, Ore.',
#  'Long Island/NYC/VT',
#  'Calamba, Philippines',
#  'Bay Areas',
#  'London and Beijing',
#  'Kendal, in my bones',
#  '???????',
#  'Cedar Rapids, Iowa',
#  'GB',
#  'Jamaica?? Japan',
#  'Sacramento, Ca',
#  'Diocese of Metuchen ',
#  'swansea',
#  'Richmond, BC',
#  'Los Angeles CA,  Washington DC',
#  'Mumbra, Navi Mumbai',
#  'of London, thinking HUB ',
#  'U.S.A',
#  'Killeen, TX',
#  'Berkshire, England',
#  'Ojai, CA',
#  'Polesworth, UK',
#  'Bethnal Green',
#  'Abilene, Texas',
#  'All Smiles Over Here?',
#  'Norn Iron',
#  'Dunedin, Otago, New Zealand',
#  "I don't know ",
#  'kenya',
#  'Gaea',
#  'Milky-way galaxy  ',
#  'Serrekunda',
#  '3905 S. Lindbergh Blvd, Sunset Hills, MO 63127',
#  'Atlanta,Ga',
#  'Wolfenbüttel, Germany',
#  'relaxing in MyBonnét',
#  '13467 Lookout Dr, Bella Vista',
#  'Port Arthur, TX',
#  'Saskatoon, Saskatchewan',
#  'Halifax, West Yorkshire UK ',
#  '?901',
#  'New York, NY USA',
#  'Chicago, IL / Rincon, PR',
#  'NYC / Wash Hights...',
#  'Portland, OR ',
#  'Clinton Township Michigan ',
#  'Istambul, Turquia',
#  'Little Rock, Ark.',
#  'Turkey',
#  'World Wide',
#  'block 69 flat 5 wuse zone 2 Ab',
#  'Los Angeles + DC',
#  'scotland ',
#  'Madrid o Cercedilla',
#  'New Freedom, PA',
#  'Somewhere on Earth ',
#  'Gods own County Yorkshire',
#  'UNITED ARAB EMIRATES',
#  'Morley, Leeds UK',
#  'Ames, IA',
#  'East Weymouth, MA',
#  'The bright side ',
#  'LA County, USA',
#  'Nairobi, Kenya ??',
#  'Abz',
#  '"..I had to find the passage back to the place I was before..\r\r\nYou can check-out any time you like\r\r\nBut you can never leave!"',
#  'Waterford',
#  'Wrentham, MA',
#  'Mahwah, NJ',
#  'Basildon, Southend, Romford, Ilford, Leicester, Peterborough & Nottingham',
#  'Amsterdam, NL',
#  'Tilburg The Netherlands',
#  'Thames Valley',
#  'Goa',
#  'Miletus/Grand Cayman',
#  'Out Here',
#  'Salem, IN',
#  'Stowmarket',
#  'Lorain County, Ohio',
#  'Edmonton, AB',
#  'ÜT: 39.89015,-86.120108',
#  'Just around the corner',
#  'Farmington Hills',
#  'Howly, Barpeta',
#  'iPhone: 53.611340,-2.306613',
#  'Birmingham, UK',
#  'Colum?it',
#  'Mount Juliet, TN',
#  'where the heart is',
#  'Chennai ',
#  'Apple Valley, MN',
#  'Daman, India',
#  'Valley Village, CA',
#  'London base - Global & Virtual',
#  'Virtually Everywhere',
#  'Ankara TURKEY',
#  'Jaipur, India',
#  'At the Movies',
#  'Geelong, Victoria, Australia',
#  'Somewhere in Hell!',
#  'Bizerte,Bizerta-Tunisia',
#  'Perth, Australia',
#  'Harrisburg, Pennsylvania',
#  'denial',
#  'High Wycombe',
#  'Wien',
#  'India, gujarat',
#  'Outside, standing on a bucket',
#  '1AU - SF??AZ',
#  'Randolph, NJ',
#  'Yo mamas house!!',
#  'QLD, NNSW & NT',
#  'KNUST ',
#  'Somewhere in a #Marriott',
#  'Varying',
#  'S.E. United States',
#  'US \x96Europe\x96MEA-AsiaPacific',
#  'Henderson, NV',
#  'Boone, NC',
#  'Duniani',
#  'Lenexa, Kansas ',
#  'Third Stone From The Sun ',
#  'Cherry Hills Village, CO',
#  'Addu City ',
#  'Deadpool is my Patronus ',
#  'L A, CA',
#  'Luton, Bedfordshire, England',
#  'Cranberry Township, PA',
#  'Casterly Rock',
#  'Graz, Austria',
#  '????????2-2-1',
#  'Bath and North East Somerset',
#  'Somewhere on a BEACH !!',
#  'Naperville, IL',
#  'MO',
#  'PlanetJCG',
#  'Reading, Pa.',
#  'Staffordshire UK',
#  'Boston Metro',
#  'NYC-area',
#  'LA. ',
#  'Leduc, AB',
#  'Toronto | New York | London UK',
#  'New York and the World',
#  'Detmold, Germany',
#  'russell ontario',
#  'Ketchum, ID',
#  'Institute, WV',
#  'she/her ? edinburgh',
#  'Trinidad and Tobago',
#  'New York City ',
#  'W Hollywood CA',
#  "The People's Republic of Coatbridge ",
#  'Leesburg, VA',
#  'Northern VA',
#  'TPA and SF',
#  'Vancouver, B.C.',
#  'Pittsburgh',
#  'Allen, Texas',
#  'Coquitlam',
#  'London and online ',
#  'Canandaigua, NY',
#  'Chicago area, IL',
#  'Hataitai, Wellington City',
#  'Albany NY',
#  'Cuthbert, GA',
#  'Knowsley, Merseyside',
#  'Laois / Cork',
#  'Cloud Nine ',
#  'the Interwebz',
#  'Dumb Dumb Town',
#  'Arua, Uganda',
#  'Manchester, England',
#  'Paramus, NJ',
#  'Johnny depp is a ?',
#  'Kolkata/Delhi',
#  'Fragile Earth ?',
#  'ÜT: 41.859568,-72.743002',
#  'nobody, cares U.S.A',
#  'Logan, UT',
#  'Halifax, MA',
#  'Bangor, Wales',
#  'Sunny/Chilly SC',
#  'T?maki Makaurau',
#  'Washington ',
#  'Atlanta University Center',
#  'Bailiwick of Guernsey',
#  'Widnes, England ',
#  'London and Bromsgrove UK',
#  '????? ? ???? raised in Canada ',
#  'LDN, CHI, SHG & worldwide',
#  'Treaty 4 Territory-Regina, SK',
#  'Harlem-NYC, Rocky Mount-NC',
#  'Oldham',
#  'Quincy, MA',
#  'Santa Monica & San Francisco',
#  'Stockbridge, GA',
#  'Studio City, California',
#  'The Delta Quadrant',
#  'Somewhere in the US',
#  'Charlotte, NC USA',
#  'Villaviciosa de Odón - Madrid',
#  'BC Canada',
#  'Cardiff',
#  'kingslynn',
#  'Ibadan, Lagos; Nigeria etc.',
#  'Bangor Co Down ',
#  'Potsdam',
#  'City of Love PHL',
#  'Leeds',
#  'Chicago and Omaha',
#  'United States of Smash',
#  'Washington... the State.  ',
#  'TX',
#  'Madeira beach, fla',
#  'Gainesville, Fla.',
#  'Wayne County, Ohio',
#  'Thuis',
#  'Bend, OR',
#  'around',
#  'Helghan To Olympus By The Gods',
#  'Wildest dreams',
#  'nj ',
#  'Kuching, Sarawak, Malaysia',
#  'On your screen',
#  'Cambridge, Ontario',
#  'Leeds, UK',
#  'Clay, NY',
#  'Nairobi',
#  'Montreal Canada',
#  'Avusturya, Viyana',
#  'Robson Street, Vancouver, BC',
#  'your brain',
#  'Margaritaville',
#  'Fresno, CA',
#  'oban',
#  'Ulaanbaatar, Mongolia',
#  'Montreal, QC',
#  'Bridport, England',
#  'Melbourne, Victoria',
#  'Chilliwack, British Columbia',
#  'Sekondi Takoradi',
#  'So Cal',
#  'thornaby on tees',
#  'Los Angeles, CA, USA',
#  'Dartmouth, Nova Scotia, Canada',
#  '???????? adrift at Sea ',
#  'Field of West, Radstock ',
#  'Naperville & St. Charles, IL',
#  'Spartanburg, SC',
#  'Brentwood, TN',
#  'Johore Bahru | Kuala Lumpur',
#  'Newark  NJ',
#  'Island Paradise of Kaimana - hidden off California coast.',
#  'Okinawa-shi, Okinawa',
#  'Falmouth, England',
#  'Bergamo, Lombardia',
#  'Amestris :3 kuinazas~',
#  'Walton, nr Wetherby',
#  'Ayr, Queensland',
#  'Boonwurrung land ',
#  'Pawtucket, RI',
#  'Athens, GA 30606',
#  'Huddersfield, West Yorkshire',
#  'Pakistan',
#  'Goshen, KY',
#  'San Fran, USA',
#  'Pasadena, TX',
#  'Sunnyvale, CA',
#  'Melbourne, FL',
#  'WorldWide',
#  'Everywhere/Nowhere',
#  'London & New York',
#  'Nottinghamshire, UK',
#  'Chesapeake, VA',
#  'Uganda ',
#  'Hindustan ',
#  'Various Locations',
#  'Seychelles',
#  'Venezuela',
#  'Penarth,Wales ???????',
#  'Elko New Market, MN',
#  '77(3)12',
#  'Percy St, Newcastle upon Tyne ',
#  '#AuditTheFed',
#  'Malacca, Malaysia',
#  'Mid Atlantic State, USA ??',
#  'blocked by Bongino et co.',
#  'Rotterdam',
#  'Haymarket, VA',
#  'The Cloud',
#  'Nittany Nation, USA',
#  'Google Maps, ? social distance',
#  'Los Angeles | IG: @philipersia',
#  'Loveland, CO',
#  '??????????????????????????????',
#  ' Bhagalpur,Bihar, Delhi,India',
#  'MoneyBurg',
#  'Brighton, Colorado',
#  'Barcelona, Cataluña',
#  'London Uk ??',
#  'Worrall, England',
#  'Northern CA',
#  'Research associate at IsAG',
#  'Westland, MI',
#  'Florence, Italy',
#  'Adn ',
#  'Yeet Town USA',
#  'New Delhi,Saket',
#  'Washington, D.C., USA',
#  'Ghana Accra',
#  'Probs dreaming about dunkaroos',
#  'Munsyari, India',
#  'Honolulu, Hawaii, USA',
#  'S A V A N N A H',
#  'Email: richard@coilpod.com',
#  'taking a walk on the OddSide',
#  'Carlsbad, California',
#  'Gauteng',
#  'Salford',
#  'Sarasota,FL, USA',
#  'Ferguson at Heart     ',
#  'Philly ',
#  'Gadsden\x92s Wharf, S. Carolina',
#  '3405 Pennsylvania Common, Fremont, California, 94536, USA',
#  'Watching TV in the Kitchen',
#  'NJ via CHI via OKC',
#  'Roermond, Limburg',
#  'STL, USA',
#  'Tipperary 4 work Laois 4 play',
#  'Plastic Beach',
#  'Shrewsbury, Shropshire, UK',
#  'New South Wales, Australia',
#  'T?maki-makau-rau',
#  'transgender cultural district',
#  'Lausanne - Switzerland',
#  'Santa Fe, New Mexico',
#  'Uganda',
#  'tonbridge, kent, england',
#  'Plainville, MA',
#  'Alabama, USA',
#  'Tchad',
#  'London/South East',
#  'LA County',
#  'Puget Sound',
#  'Wiltshire UK',
#  'Queenslander ??',
#  'Jersey City, NJ',
#  'in a simulation idk',
#  'Right beside you',
#  'Abu Dhabi, United Arab Emirates',
#  'Mars gezegeni ',
#  'Pittsburgh-ish, PA',
#  'Chicago USA',
#  'North Carolina',
#  '10822 50 Street SE Calgary',
#  'Great State of Texas',
#  'Richmond, VA',
#  'Tarentum, PA',
#  'Memphis,TN',
#  'Scotland. London. Los Angeles',
#  'Cefas Weymouth Laboratory, UK',
#  'Long Beach, CA',
#  'Exeter, Devon, England',
#  'Long Beach/Seal Beach/LA',
#  'Occupied Duwamish Territory',
#  'Nashua, NH',
#  'Parktown',
#  'Lawrence, Kansas',
#  'cornwall',
#  'Planet earth followers can DM!',
#  'Iowa',
#  'Buenos Aires',
#  'Room LoL',
#  '#GordDowniesCanada',
#  'Issaquah, WA',
#  'Saskatchewan',
#  'Aurora, ON CANADA',
#  'Surrey',
#  'Kota Kinabalu, Sabah',
#  'Chesapeake',
#  'Washington, DC and Roanoke, VA',
#  'The Outet Rim',
#  'Ventnor, Europe',
#  'My Room',
#  'Planet Earth: Manila, PH',
#  "this scepter'd isle",
#  'Shiga Prefecture, Japan',
#  'Great Yarmouth, England',
#  'Las Pinas City, National Capit',
#  'EVERYWHERE!',
#  'Tungan-Mai-Igwai, Nigeria.',
#  "Jo's Diner, American South",
#  'jos ',
#  'in your dreams ',
#  'Ohio, USA XBL= VVILDELF',
#  'Athi river ',
#  'Toronto & Montreal, Canada',
#  'Wayne County, MI',
#  'San Diego',
#  'Nairobi, Kenya.',
#  'Lansdale, PA',
#  'Widgee',
#  'Saragossa, Spain',
#  'N/a',
#  'stockton on tees',
#  'Trinidad y Tobago',
#  'Germany - acting globally ',
#  'Belfast and Dublin',
#  'Seeleys Bay, ON CANADA',
#  'Howell, MI',
#  'Aberdare,  South Wales',
#  '34787',
#  'In A Galaxy Far, Far Away...',
#  'TheMissGinger@protonmail.ch',
#  'Northamptonshire, UK',
#  'Milpitas, CA',
#  'Roma, Lazio',
#  'Fujairah, UAE.',
#  'West Coast ',
#  'Lexington, KY',
#  'West Cumbria',
#  '10028',
#  '956',
#  'Comilla, Bangladesh',
#  '163 Fountain St, Branson, MO',
#  'Berlin, Germany ',
#  'Mumbai , India',
#  'Convenience Stores Worldwide',
#  'Deep in the ? ',
#  'gm_hellmind',
#  'Mars ',
#  'Queens, New York',
#  '65 Maple Ave Florida, NY 10921',
#  'Denver Metro Area',
#  'Bodmin, England',
#  'Glasgow',
#  'Maui,HI',
#  'Hampshire and Surrey, England',
#  'global ?',
#  'Hiroshima',
#  'Emerging Markets',
#  'Bedford',
#  'AMERICA',
#  'Stuttgart, Germany',
#  'Canada - Toronto - UWO',
#  'Santa Pola',
#  'Central Indiana',
#  'Callawassie Island, SC',
#  'Glenview, Illinois',
#  '14 ?????????',
#  'Jaha Jhumka Gira Tha',
#  'Sao Paulo, Brasil',
#  'JAPAN RUGBY TEST MATCH 2020 @JRFURugby @JRFUMedia v @WelshRugbyUnion(6/27??) v @EnglandRugby(7/4?11?????)  @Scotlandteam(11/14) @IrishRugby(11/21)',
#  'New Zealand and UK',
#  'new york',
#  'Dickson, TN',
#  'IBadan/ABuJa/NIGer/LAGos/OGun+',
#  'Lagos nigeria',
#  'NJ/NYC',
#  'on board my Corbin 39 Sailboat',
#  'Oxfordshire',
#  'NY/TX',
#  'Bow, NH',
#  'Republic of the Philippines',
#  'Sydney - Canberra - Australia',
#  'NYC | LA | Miami | DC',
#  'This is not here.',
#  'East Coast, USA',
#  'Liverpool ',
#  'bullshit boulevard',
#  'London. Paris. Cardiff.',
#  'Hamilton/Haldimand',
#  'Elmvale, Ontario',
#  'based in UK ',
#  'West Yorkshire ',
#  'León ',
#  'Joliet, IL',
#  'No man is an island',
#  'Boise, Idaho',
#  'Land of Rationality',
#  'Stafford, VA',
#  'Melbourne, Victoria, Australia',
#  'Kampala | Uganda. ',
#  'Portland, Oregon',
#  'Bloomington, MN',
#  'Rivendell ',
#  'Vijayawada, India',
#  'South East, England',
#  'Wandering globally...',
#  'Inland Empire',
#  'Rome, Lazio',
#  'wreaking havoc',
#  'Mexico City, Mexico',
#  'Near Detroit River in ON or MI',
#  'Wales U.K.',
#  'Richardson, TX',
#  'Champagne taste, beer budget.',
#  'Mississauga, Ontario, CANADA',
#  'los angeles ca',
#  'Truro, Nova Scotia',
#  'LATAM - MENA - EUR - ASIA',
#  'Chesterfield, VA',
#  'University of Ottawa',
#  'Thane, India',
#  'Kelowna BC Tel Aviv Israel',
#  '???? ??????',
#  'Juba south sudan',
#  'uk',
#  'ghana',
#  'ÜT: 40.755893,-73.985638',
#  ' 75, 12th Street, Parkhurst',
#  'Park Slope, Brooklyn',
#  'Watertown, NY',
#  'West coast',
#  'Manchester + London',
#  'Ballito KZN ',
#  'Newport Beach, California',
#  'Rochdale, England',
#  'Occupied Cowlitz Lands',
#  'Suburbia in Upstate, NY',
#  'Cheshire',
#  'San Francisco, California',
#  'Torino',
#  'Douglas, AZ',
#  'Bathinda, Punjab',
#  'Srinagar, Kashmir',
#  'Harrogate district',
#  'Ashburn, VA',
#  'Lake City, FL',
#  'China SEA Italy Turkey Egypt',
#  ...}

# %% [markdown]
# Furthermore, the location is missing in an approximate 20% of datapoints

# %%
df.isna().sum()
# Out:
# UserName            0
# ScreenName          0
# Location         8590
# TweetAt             0
# OriginalTweet       0
# Sentiment           0
# dtype: int64

# %%
sns.countplot(data=df, x="Sentiment", order=['Extremely Negative', 'Negative', 'Neutral', 'Positive', 'Extremely Positive'])
# Out:
# <AxesSubplot:xlabel='Sentiment', ylabel='count'>

# %% [markdown]
# # Data Cleaning
# Next let's identify potentially problematic patterns using regex.

# %%
clean_df = df.copy()

# %% [markdown]
# Clean up whitespace.

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('[\n\r]', ' ', regex=True)
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace(' +', ' ', regex=True)

# %% [markdown]
# Remove repeated question marks.

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('\?+', '?', regex=True)
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('(?:\? ?)+', '?', regex=True)

# %% [markdown]
# Remove URLs.

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('http[^ ]*', ' ', regex=True)

# %% [markdown]
# Change ampercent sign and the xml entity to "and" word.

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('(&amp;)|&', 'and', regex=True)

# %% [markdown]
# Remove hashtags

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('#\w+', ' ', regex=True)

# %% [markdown]
# Remove reference to twitter Users.
#
# Example: '@bbc'

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace('@[^ ]+', ' ', regex=True)

# %% [markdown]
# remove duplicate whitespaces

# %%
clean_df['OriginalTweet'] = clean_df['OriginalTweet'].str.replace(' +', ' ', regex=True)

# %% [markdown]
# ...and lastly drop tweets, which likely don't contain a word.

# %%
clean_df = clean_df[clean_df['OriginalTweet'].str.contains('\w{4,}')]

# %% [markdown]
# Change labels to integer format.

# %%
set(clean_df['Sentiment'])
# Out:
# {'Extremely Negative', 'Extremely Positive', 'Negative', 'Neutral', 'Positive'}

# %%
label_dict = {
    'Extremely Negative': 0, 
    'Negative': 0, 
    'Neutral': 1, 
    'Positive': 2,
    'Extremely Positive': 2
}
clean_df['SentimentCode'] = clean_df['Sentiment'].replace(label_dict)
clean_df
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# 5          3804       48756      ÜT: 36.319708,-82.363649  16-03-2020
# ...         ...         ...                           ...         ...
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                                                                                                                                                                                                                                OriginalTweet  \
# 1              advice Talk to your neighbours family to exchange phone numbers create contact list with phone numbers of neighbours schools employer chemist GP set up online shopping accounts if poss adequate supplies of regular meds but not over order
# 2                                                                                                                                               Coronavirus Australia: Woolworths to give elderly, disabled dedicated shopping hours amid COVID-19 outbreak
# 3                                                                              My food stock is not the only one which is empty... PLEASE, don't panic, THERE WILL BE ENOUGH FOOD FOR EVERYONE if you do not take more than you need. Stay calm, stay safe.
# 4                                                        Me, ready to go at supermarket during the outbreak. Not because I'm paranoid, but because my food stock is litteraly empty. The is a serious thing, but please, don't panic. It causes shortage...
# 5                                     As news of the regions first confirmed COVID-19 case came out of Sullivan County last week, people flocked to area stores to purchase cleaning supplies, hand sanitizer, food, toilet paper and other goods, reports
# ...                                                                                                                                                                                                                                                      ...
# 41152                                                                                                                                                                                  Airline pilots offering to stock supermarket shelves in lockdown -19
# 41153                                                                                                             Response to complaint not provided citing COVID-19 related delays. Yet prompt in rejecting policy before consumer TAT is over. Way to go ?
# 41154                                                                                                                                                                 You know its getting tough when is rationing toilet paper martinsville, help us out!!
# 41155                                                                                                                                                                               Is it wrong that the smell of hand sanitizer is starting to turn me on?
# 41156   Well new/used Rift S are going for $700.00 on Amazon rn although the normal market price is usually $400.00 . Prices are really crazy right now for vr headsets since HL Alex was announced and it's only been worse with COVID-19. Up to you whethe
#
#                 Sentiment  SentimentCode
# 1                Positive              2
# 2                Positive              2
# 3                Positive              2
# 4      Extremely Negative              0
# 5                Positive              2
# ...                   ...            ...
# 41152             Neutral              1
# 41153  Extremely Negative              0
# 41154            Positive              2
# 41155             Neutral              1
# 41156            Negative              0
#
# [41106 rows x 7 columns]

# %% [markdown]
# Put all these cleaning steps in a function called 'clean_dataframe' and apply the same logic to the test set

# %%
from clean_data import clean_dataframe

# %%
clean_df_test = clean_dataframe(df_test, tweet_option='remove_all')

# %%
clean_df.to_csv('./data/Corona_NLP_train_clean_no_hash.csv')
clean_df_test.to_csv('./data/Corona_NLP_test_clean_no_hash.csv')
